# %% [markdown]
# <a href="https://colab.research.google.com/github/khatrhrjb0-gif/ds_class/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello")
# Out:
# hello
